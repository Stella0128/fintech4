# %% [markdown]
# # 프로그래밍 방법 3가지
# ## 1. 절차적 프로그래밍
# * 프로그래밍을 순차적으로 하는 것
# * 코드가 위에서 아래로 절차적으로 실행
# ```python
# nums = [1,2,3,4]
# squares = []
# for i in nums:
#     squares.append(i**2)
# print(squares)
# ```
#
# ## 2.함수형 프로그래밍
# * 여러 개의 함수를 작성해서 함수에 기반해 프로그램이 실행
# * 코드의 재사용 가능
# * 유지보수가 쉬워짐
# * 버그 발생률이 낮고 예측 가능성이 높음
# * 병렬처리, 동시성 처리에 강함 - 멀티 코어를 이용할 때 유리
# ```python
# # 리스트의 제곱합 구하기
# nums = [1,2,3,4]
# squares = list(map(lambda x: x ** 2,  nums))
# print(squares)
# ```
#
# ## 3. 객체지향 프로그래밍
# * JAVA, C++
# * 클래스 기반으로 프로그래밍
# * 캡슐화, 상속, 다형성 같은 개념 사용
# * 코드를 재사용하는데 특화
# * 여러사람이 이용할 때 같은 코드를 독립적으로 사용 가능
# ```python
# class NumberList:
#     def __init__(self, numbers):
#         self.numbers = numbers
#     def squared(self):
#         return [x**2 for x in self.numbers]
#
# squared = NumberList([1, 2, 3, 4]).squared()
# ```

# %% [markdown]
# # 클래스가 필요한 이유

# %% [markdown]
# * 이전에 계산했던 결과를 기억하는 계산기 만들기

# %%
result_cal = 0
def add(num, result_cal):
    result_cal += num
    return result_cal

# %%
add(3, 0)
# Out:
# 3

# %%
print(result_cal)
# Out:
# 0

# %%
# 함수 내부의 매개변수는 함수 내부에서만 사용됨
result_cal = 0
def add(num, result_cal):
    result_cal += num
    print("함수 내부의 result_cal id: ", id(result_cal))
    return result_cal

# %%
add(3,0)
print("함수 내부의 result_cal id: ", id(result_cal))
# Out:
# 함수 내부의 result_cal id:  2037234598192
# 함수 내부의 result_cal id:  2037234598096

# %%
result_cal
# Out:
# 0

# %% [markdown]
# * 전역변수를 함수 내부에서 사용할 수 있도록 하는 방법
#   * global 전역변수명

# %%
result_cal = 0
def add(num):
    global result_cal 
    result_cal += num
    print("함수 내부의 result_cal id: ", id(result_cal))
    return result_cal

# %%
print(add(3))
print("함수 내부의 result_cal id: ", id(result_cal))
# Out:
# 함수 내부의 result_cal id:  2037234598288
# 6
# 함수 내부의 result_cal id:  2037234598288

# %% [markdown]
# * 이전 값을 기억하는 계산기를 둘리와 길동이가 같이 쓰려고 할 때

# %%
# 둘리의 계산기
result_cal = 0
def add(num):
    global result_cal 
    result_cal += num
    print("함수 내부의 result_cal id: ", id(result_cal))
    return result_cal

# %%
add(5)
# Out:
# 함수 내부의 result_cal id:  2037234598672
# 18

# %%
# 길동이의 계산기
result_cal = 0
def gil_add(num):
    global result_cal 
    result_cal += num
    print("함수 내부의 result_cal id: ", id(result_cal))
    return result_cal

# %%
gil_add(10)
# Out:
# 함수 내부의 result_cal id:  2037234598416
# 10

# %% [markdown]
# # 클래스 만들기
# * 클래스의 이름은 대문자로 시작하는 카멜 표기법으로 만들어 준다.
# * 클래스 안에 정의하는 함수는 메서드라고 부른다.
# * 메서드는 인스턴스명.메서드명 형태로 사용.
# * 인스턴스는 클래스로 만든 제품을 사용자에게 준 것이라고 생각하면 된다.
# * 클래스는 공장, 인스턴스는 공장에서 만든 제품을 받은 사용자.
# * 클래스는 공장에서 만든 계산기, 인스턴스는 만들어진 계산기를 배송 받는 사용자

# %%
# 공장에서 계산기 설계도를 만듦 => class
class Calc():
    def __init__(self):
        self.result = 0
    def add(self, num):
        self.result += num
        return self.result

# %%
# 길동이(인스턴스)에게 계산기(class)를 배송
gildong = Calc()

# %%
# 기능을 사용할 때는 사용자명(길동이, 인스턴스).메서드명(add)
gildong.add(4)
# Out:
# 11

# %%
# 둘리(인스턴스)에게 계산기(class)를 배송
dul = Calc()

# %%
dul.add(10)
# Out:
# 10

# %%
# 함수
len("이것은 함수입니다. 인스턴스가 필요 없어요")
# Out:
# 23

# %%
# 메서드
print(type("이것은 함수입니다. 인스턴스가 필요 없어요"))
# Out:
# <class 'str'>

# %%
"이것은 함수입니다. 인스턴스가 필요 없어요".items()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 "이것은 함수입니다. 인스턴스가 필요 없어요".items()
#
# AttributeError: 'str' object has no attribute 'items'

# %%
Calc().add(3)
# Out:
# 3

# %% [markdown]
# # 클래스 사용 방법
# * 변수에 클래스를 담아서 인스턴스 생성
# * 공장에서 만든 커피머신을 사용자에게 배송
# ```python
# 인스턴스 변수명 = 클래스명() # 인스턴스 생성
# ```
# * 인스턴스를 생성하고 나면
# ```python
# 인스턴스 변수명.메서드() # 형식으로 클래스에 정의한 메서드를 사용할 수 있다.
# ```

# %%
sally = Calc()

# %%
sally.add(5)
# Out:
# 5

# %% [markdown]
# # 메서드(method)
# * 클래스 안에 정의하는 함수
# * 클래스에 기능을 만들어 준다.
# * 기본적으로는 **반드시 self가 들어가야 함**
# ```python
# def 변수명(self, 매개변수1, 매개변수2, ..., *args, **kwargs):
#     self.매개변수1 = 매개변수1
#     self.매개변수2 = 매개변수2
# ```

# %% [markdown]
# * 사칙연산이 가능한 FourCal 계산기 만들기

# %%
class FourCal():
    # 데이터를 입력 받는 역할의 setdata method
    def setdata(self, num1, num2):
        self.num1 = num1
        self.num2 = num2
        print("self.num1:", self.num1)
        print("self.num2:", self.num2)

# %%
sam = FourCal()

# %%
sam.setdata(3, 5)
# Out:
# self.num1: 3
# self.num2: 5

# %% [markdown]
# * FourCal에 사칙연산 기능 넣기

# %%
class FourCal():
    # 데이터를 입력 받는 역할의 setdata method
    def setdata(self, num1, num2):
        self.num1 = num1
        self.num2 = num2
        print("self.num1:", self.num1)
        print("self.num2:", self.num2)
        
    def add(self):
        result = self.num1 + self.num2
        return result
    
    def sub(self):
        result = self.num1 - self.num2
        return result
    
    def mul(self):
        result = self.num1 * self.num2
        return result
    
    def div(self):
        result = self.num1 / self.num2
        return result

# %%
sam = FourCal()

# %%
sam.add()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 sam.add()
#
# Cell In[45], line 10, in FourCal.add(self)
#       9 def add(self):
# ---> 10     result = self.num1 + self.num2
#      11     return result
#
# AttributeError: 'FourCal' object has no attribute 'num1'

# %%
sam.setdata(10,5)
# Out:
# self.num1: 10
# self.num2: 5

# %%
sam.add()
# Out:
# 15

# %%
sam.sub()
# Out:
# 5

# %%
sam.mul()
# Out:
# 50

# %%
sam.div()
# Out:
# 2.0

# %% [markdown]
# # 생성자
# * 클래스를 실행해서 인스턴스를 만들 때 자동 실행 되고 초기값을 받도록 해주는 메서드
# * 생성자(constructor)는 객체(인스턴스)가 생성될 때 자동으로 호출되는 메서드
# * 클래스 내에서 메서드명으로 \_\_init__를 사용하면 그것이 생성자가 된다.

# %% [markdown]
# * 생성자를 이용해 초기값을 받는 FourCal2 class

# %%
class FourCal2():
    # 생성자
    def __init__(self, num1, num2):
        self.num1 = num1
        self.num2 = num2
        print("self.num1:", self.num1)
        print("self.num2:", self.num2)
        
    def add(self):
        result = self.num1 + self.num2
        return result
    
    def sub(self):
        result = self.num1 - self.num2
        return result
    
    def mul(self):
        result = self.num1 * self.num2
        return result
    
    def div(self):
        result = self.num1 / self.num2
        return result

# %%
sally = FourCal2()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 sally = FourCal2()
#
# TypeError: FourCal2.__init__() missing 2 required positional arguments: 'num1' and 'num2'

# %%
sally = FourCal2(10, 5)
# Out:
# self.num1: 10
# self.num2: 5

# %%
sally.add()
# Out:
# 15

# %%
sally.sub()
# Out:
# 5

# %%
sally.mul()
# Out:
# 50

# %%
sally.div()
# Out:
# 2.0

# %% [markdown]
# # 클래스의 상속
# * 어떤 클래스를 만들 때 다른 클래스의 기능을 물려받는 것
# * 기존 클래스에 기능을 추가할 때
# * A클래스를 상속 받아 B클래스를 생성한다고 할 때
# * B클래스는 A클래스의 모든 기능을 사용할 수 있다.

# %% [markdown]
# * FourCal2를 상속 받아 제곱 기능을 추가한 MoreFourCal 만들기

# %%
class MoreFourCal(FourCal2):
    def pow(self):
        result = self.num1 ** self.num2
        return result

# %%
dul = MoreFourCal()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 dul = MoreFourCal()
#
# TypeError: FourCal2.__init__() missing 2 required positional arguments: 'num1' and 'num2'

# %%
dul = MoreFourCal(10, 5)
# Out:
# self.num1: 10
# self.num2: 5

# %%
dul.add()
# Out:
# 15

# %%
dul.sub()
# Out:
# 5

# %%
dul.mul()
# Out:
# 50

# %%
dul.div()
# Out:
# 2.0

# %%
dul.pow()
# Out:
# 100000

# %% [markdown]
# # 메서드 오버라이딩(method overriding)
# * 부모 클래스에서 상속한 메서드를 자식 클래스에서 동일한 이름으로 기능을 재정의 하는 것
# * 같은 이름의 메서드의 기능을 바꾸거나, 수정할 때 사용

# %%
kim = MoreFourCal(100,0)
# Out:
# self.num1: 100
# self.num2: 0

# %%
kim.add()
# Out:
# 100

# %%
kim.sub()
# Out:
# 100

# %%
kim.mul()
# Out:
# 0

# %%
kim.div()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 kim.div()
#
# Cell In[55], line 22, in FourCal2.div(self)
#      21 def div(self):
# ---> 22     result = self.num1 / self.num2
#      23     return result
#
# ZeroDivisionError: division by zero

# %%
kim.pow()
# Out:
# 1

# %% [markdown]
# * FourCal2의 div() 메서드는 num2에 0이 입력 될 경우 에러 발생
# * SafeFourCal을 만들고 FourCal2를 상속 받은 후 div 함수를 재정의 하여 에러를 없앰
# * 이 때 div함수를 재정의 하는 것을 overrideing이라고 함

# %%
class SafeFourCal(FourCal2):
    def div(self):
        if self.num2 == 0:
            return 0
        else:
            return self.num1 / self.num2

# %%
kim = SafeFourCal(100,0)
# Out:
# self.num1: 100
# self.num2: 0

# %%
kim.add()
# Out:
# 100

# %%
kim.sub()
# Out:
# 100

# %%
kim.mul()
# Out:
# 0

# %%
kim.div()
# Out:
# 0

# %%
kim2 = FourCal2(100,0)
kim2.div()
# Out:
# self.num1: 100
# self.num2: 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[89], line 2
#       1 kim2 = FourCal2(100,0)
# ----> 2 kim2.div()
#
# Cell In[55], line 22, in FourCal2.div(self)
#      21 def div(self):
# ---> 22     result = self.num1 / self.num2
#      23     return result
#
# ZeroDivisionError: division by zero

# %% [markdown]
# # 메서드 오버로딩
# * 한 클래스 안에서 동일 메서드의 기능을 다르게 재정의
# * 동일한 이름의 메서드가 기능이 약간 변경된 채로 여러개 존재
# ```python
# def add(self, num1, num2):
# def add(self, num1, num2, num3):
# def add(self, num1, num2, num3, num4):
# ```
#   * 값의 수가 달라지면 알아서 다르게 실행
# * python에서는 메서드 오버로딩이 기본 지원되지 않음
# * multipledispatch 모듈을 설치해야 사용 가능

# %%
class OverloadingEx():
    def add(self, num1, num2):
        return num1 + num2
    def add(self, num1, num2, num3, num4):
        return num1 + num2 + num3
    def add(self, num1, num2, num3, num4):
        return num1 + num2 + num3 + num4

# %%
sam = OverloadingEx()

# %%
# 파이썬은 위에서 아래로 순차적으로 실행하기 때문에 add 메서드를 가장 아래에 정의된 것으로 덮어씀.
sam.add(3, 5)
# Out:
# 8

# %%
class OverloadingEx():
    def add(self, num1, num2, num3, num4):
        return num1 + num2 + num3
    def add(self, num1, num2, num3, num4):
        return num1 + num2 + num3 + num4
    def add(self, num1, num2):
        return num1 + num2

# %%
sam = OverloadingEx()

# %%
# 순서를 바꾸면 실행됨
sam.add(3, 5)
# Out:
# 8

# %%
# ! pip install multipledispatch
# Out:
# Collecting multipledispatch
#   Downloading multipledispatch-1.0.0-py3-none-any.whl.metadata (3.8 kB)
# Downloading multipledispatch-1.0.0-py3-none-any.whl (12 kB)
# Installing collected packages: multipledispatch
# Successfully installed multipledispatch-1.0.0

# %%
from multipledispatch import dispatch

# %%
class OverloadingEx():
    @dispatch(int, int)
    def add(self, num1, num2):
        return num1 + num2
    
    @dispatch(int, int, int)
    def add(self, num1, num2, num3, num4):
        return num1 + num2 + num3
    
    @dispatch(int, int, int, int)
    def add(self, num1, num2, num3, num4):
        return num1 + num2 + num3 + num4
    
    @dispatch(float, float)
    def add(self, num1, num2):
        return num1 + num2

# %%
sam = OverloadingEx()

# %%
sam.add(3, 5)
# Out:
# 8

# %%
sam.add(3.0, 5)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[105], line 1
# ----> 1 sam.add(3.0, 5)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\multipledispatch\dispatcher.py:435, in MethodDispatcher.__call__(self, *args, **kwargs)
#     433 func = self.dispatch(*types)
#     434 if not func:
# --> 435     raise NotImplementedError(
#     436         "Could not find signature for %s: <%s>"
#     437         % (self.name, str_signature(types))
#     438     )
#     439 return func(self.obj, *args, **kwargs)
#
# NotImplementedError: Could not find signature for add: <float, int>

# %%
sam.add(3.0, 5.0)
# Out:
# 8.0

# %% [markdown]
# # 클래스 속성과 인스턴스 속성
# * 클래스 속성: 클래스 전체에서 공유하는 속성(변수), 모든 인스턴스에서 공유 ex) 도어락 초기 비밀번호 = 0000
# * 인스턴스 속성: 인스턴스에서만 사용하는 속성, 인스턴스간 공유 안됨 ex) 구매 및 설치 후 사용자 설정 비밀번호
# * 도어락

# %%
class DoorLock():
    password = "0000" # 클래스 속성

# %%
kim = DoorLock()

# %%
kim.password
# Out:
# '0000'

# %%
an = DoorLock()
an.password
# Out:
# '0000'

# %%
# kim은 공장 초기화 비번을 1234로 변경
kim.password = "1234"

# %%
kim.password
# Out:
# '1234'

# %%
an.password
# Out:
# '0000'

# %% [markdown]
# # 비공개 클래스 속성
# * \_\_변수명: 비공개 속성
# * 보안이 필요해서 남들에게 정보를 노출하고 싶지 않을 때 사용
#   * 숨김처리 -> 조회가 되지 않음

# %%
class PInfo():
    lastname = "홍"
    __first_name = "길동"
    __password = "9513"

# %%
kim = PInfo()

# %%
kim.lastname
# Out:
# '홍'

# %%
kim.__first_name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[124], line 1
# ----> 1 kim.__first_name
#
# AttributeError: 'PInfo' object has no attribute '__first_name'

# %%
kim.__password
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[118], line 1
# ----> 1 kim.__password
#
# AttributeError: 'PInfo' object has no attribute '__password'

# %% [markdown]
# * 비공개 클래스 속성을 직접 출력하려고 하면 에러
# * 클래스 내에서 메서드를 만들어서 출력하면 출력 가능

# %%
class PInfo():
    lastname = "홍"
    __first_name = "길동"
    __password = "9513"
    
    def print_name(self):
        print(self.__first_name)
        
    def print_pw(self):
        print(self.__password)

# %%
hong = PInfo()

# %%
hong.print_name()
# Out:
# 길동

# %%
hong.print_pw()
# Out:
# 9513

# %% [markdown]
# # 정적메서드 static method
# * 인스턴스를 만들지 않고도 클래스의 메서드를 바로 사용할 수 있는 메서드
# * 메서드 위에 @staticmethod라는 데코레이터를 붙여서 만든다.
# * static method는 self를 받지 않으므로 인스턴스 속성, 인스턴스 메서드가 필요하지 않을 때 사용

# %%
class Static_Cal():
    @staticmethod
    def add(a, b):
        print(a + b)
        
    @staticmethod
    def sub(a, b):
        print(a - b)

# %%
Static_Cal.add(3, 5)
# Out:
# 8

# %%
Static_Cal.sub(3, 5)
# Out:
# -2

# %%
sam = Static_Cal()

# %%
sam.add(5,10)
# Out:
# 15

# %%
class Static_Cal():
    
    def add(a, b):
        print(a + b)
        
    
    def sub(a, b):
        print(a - b)

# %%
sally = Static_Cal()

# %%
sally.add(3, 5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[134], line 1
# ----> 1 sally.add(3, 5)
#
# TypeError: Static_Cal.add() takes 2 positional arguments but 3 were given

# %%
Static_Cal().add(3,5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[135], line 1
# ----> 1 Static_Cal().add(3,5)
#
# TypeError: Static_Cal.add() takes 2 positional arguments but 3 were given

# %% [markdown]
# # 클래스 메서드 class method
# * 메서드 위에 @classmethod를 붙여서 만든다.
# * 클래스 메서드의 첫 번째 매개변수에서는 cls를 지정해야 한다. (self X)
# * 클래스 메서드도 static method 처럼 인스턴스 생성 없이 호출 가능하다.
# * 클래스 메서드는 메서드 안에서 클래스 속성, 클래스 메서드에 접근해야 할 때 사용한다.

# %%
class Factory():
    n_coffee_machine = 0 # 클래스 속성
    
    def __init__(self):
        # 인스턴스가 생성 될 때 클래스 속성에 1을 더함
        Factory.n_coffee_machine += 1
        
    @classmethod
    def print_n_coffee_machine(cls):
        print(f"{cls.n_coffee_machine}개가 제조되었습니다.")

# %%
Factory().n_coffee_machine
# Out:
# 7

# %%
sam = Factory()

# %%
sam.n_coffee_machine
# Out:
# 8

# %% [markdown]
# ## 클래스 메서드는 init 생성자 외에 다른 방식으로 인스턴스를 생성할 때 활용
# * 특히 입력 데이터 형식이 다양할 때 유용

# %%
class Date:
    def __init__(self, year, month, day):
        self.year = year
        self.month = month
        self.day = day
        
    # "YYYY-MM-DD 형식의 문자열로 데이터를 받고 싶음"
    @classmethod
    def from_string(cls, date_str):
        year, month, day = map(int, date_str.split("-"))
        return cls(year, month, day) # cls를 사용해 인스턴스 생성
    
    def today(self):
        print(f"{self.year}년 {self.month:02d}월 {self.day:02d}일")

# %%
sam = Date(2026, 1, 16)

# %%
sam.today()
# Out:
# 2026년 01월 16일

# %%
sally = Date("2026-01-16")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[153], line 1
# ----> 1 sally = Date("2026-01-16")
#
# TypeError: Date.__init__() missing 2 required positional arguments: 'month' and 'day'

# %%
y, m ,d = map(int, "2026-01-16".split("-"))
print(y, m, d)
# Out:
# 2026 1 16

# %%
sally = Date.from_string("2026-01-16")

# %%
sally.today()
# Out:
# 2026년 01월 16일

# %% [markdown]
# # 추상 클래스 abc(Abstract Base Class) = to-do list
# * abc 모듈 필요
# * 추상 클래스는 추상 클래스를 상속 받아 클래스를 만들 때 반드시 만들어야 하는 메서드를 지정해주는 클래스
# * 규칙을 부여해서 그 규칙에 따라 클래스를 만들도록 강제함
# * 추상 클래스를 상속 받은 클래스는 반드시 추상 클래스에서 정의한 메서드를 overriding으로 구현해야 한다.
# * ex) 이력서 양식 맞추어 내용 적기

# %%
from abc import *

# %%
# 추상 클래스
class CoffeeBase(metaclass = ABCMeta):
    @abstractmethod
    def bean_input(self):
        pass
    
    @abstractmethod
    def grind(self):
        pass

# %%
sam = CoffeeBase()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[160], line 1
# ----> 1 sam = CoffeeBase()
#
# TypeError: Can't instantiate abstract class CoffeeBase with abstract methods bean_input, grind

# %%
class CoffeeMachine(CoffeeBase):
    def b_in(self):
        print("커피 원두 넣기")

# %%
sam = CoffeeMachine()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[162], line 1
# ----> 1 sam = CoffeeMachine()
#
# TypeError: Can't instantiate abstract class CoffeeMachine with abstract methods bean_input, grind

# %%
class CoffeeMachine(CoffeeBase):
    def bean_input(self):
        print("커피 원두 넣기")

# %%
sam = CoffeeMachine()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[166], line 1
# ----> 1 sam = CoffeeMachine()
#
# TypeError: Can't instantiate abstract class CoffeeMachine with abstract method grind

# %%
class CoffeeMachine(CoffeeBase):
    def bean_input(self):
        print("커피 원두 넣기")
    
    def grind(self):
        print("커피 원두 갈기")

# %%
sam = CoffeeMachine()

# %%
sam.bean_input()
# Out:
# 커피 원두 넣기

# %%
sam.grind()
# Out:
# 커피 원두 갈기
