# %% [markdown]
# 1. 빈 딕셔너리 'empty_dict'를 생성하고 출력하세요.

# %%
empty_dict = {}
print(empty_dict)
# Out:
# {}

# %% [markdown]
# 2. 다음과 같은 딕셔너리를 생성하고 출력하세요.
# ```
# person = {"name": "Alice", "age": 25, "city": "Seoul"}
# ```

# %%
person = {"name": "Alice", "age": 25, "city": "Seoul"}
print(person)
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'Seoul'}

# %% [markdown]
# 3. 딕셔너리 person에서 "name" 키의 값을 출력하세요.

# %%
print(person["name"])
# Out:
# Alice

# %% [markdown]
# 4. 딕셔너리 person에서 "age" 키의 값을 출력하세요.

# %%
print(person["age"])
# Out:
# 25

# %% [markdown]
# 5. 딕셔너리 person에 "job": "Engineer"를 추가하고 출력하세요.

# %%
person["job"] = "Engineer"
print(person)
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'Seoul', 'job': 'Engineer'}

# %% [markdown]
# 6. 딕셔너리 person에서 "city"의 값을 "Busan"으로 변경하고 출력하세요.

# %%
person["city"] = "Busan"
print(person)
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'Busan', 'job': 'Engineer'}

# %% [markdown]
# 7. 딕셔너리 person에서 "age" 키를 삭제하고 출력하세요.

# %%
del person["age"]
print(person)
# Out:
# {'name': 'Alice', 'city': 'Busan', 'job': 'Engineer'}

# %% [markdown]
# 8. 딕셔너리 person의 모든 키를 출력하세요.

# %%
print(person.keys())
# Out:
# dict_keys(['name', 'city', 'job'])

# %% [markdown]
# 9. 딕셔너리 person의 모든 값(value)을 출력하세요.

# %%
print(person.values())
# Out:
# dict_values(['Alice', 'Busan', 'Engineer'])

# %% [markdown]
# 10. 딕셔너리 person의 모든 키-값 쌍을 출력하세요.

# %%
print(person.items())
# Out:
# dict_items([('name', 'Alice'), ('city', 'Busan'), ('job', 'Engineer')])

# %% [markdown]
# 11. "email" 키가 딕셔너리 person에 존재하는지 확인하세요.

# %%
"email" in person
# Out:
# False

# %% [markdown]
# 12. person에서 "job"을 제거하고 출력하세요.

# %%
del person["job"]
print(person)
# Out:
# {'name': 'Alice', 'city': 'Busan'}

# %% [markdown]
# 13. person 딕셔너리의 모든 키-값 쌍을 초기화하고 출력하세요.

# %%
person.clear()
print(person)
# Out:
# {}

# %% [markdown]
# 14. 중첩 딕셔너리를 student 변수에 생성하고 출력하세요.
# ```
# student = {"name": "Bob",
#  "grades": {"math": 85, "science": 90, "history": 80}
# }
# ```

# %%
student = {"name": "Bob", "grades": {"math": 85, "science": 90, "history": 80}}
print(student)
# Out:
# {'name': 'Bob', 'grades': {'math': 85, 'science': 90, 'history': 80}}

# %% [markdown]
# 15. student에서 "science" 점수를 출력하세요.

# %%
print(student["grades"]["science"])
# Out:
# 90

# %% [markdown]
# 16. student의 "grades"에 "english": 95를 추가하고 출력하세요.

# %%
student["grades"]["english"] = 95
print(student)
# Out:
# {'name': 'Bob', 'grades': {'math': 85, 'science': 90, 'history': 80, 'english': 95}}

# %% [markdown]
# 17. student의 "math" 점수를 88로 변경하고 출력하세요.

# %%
student["grades"]["math"] = 88
print(student)
# Out:
# {'name': 'Bob', 'grades': {'math': 88, 'science': 90, 'history': 80, 'english': 95}}

# %% [markdown]
# 18. student에서 "history" 점수를 삭제하고 출력하세요.

# %%
del student["grades"]["history"]
print(student)
# Out:
# {'name': 'Bob', 'grades': {'math': 88, 'science': 90, 'english': 95}}

# %% [markdown]
# 19. 딕셔너리 student에서 setdefault를 이용하여 "total"이란 키를 만들고 math, science, english의 합계를 입력하세요.
# 단, 합계를 구할 때 값을 수동입력 하지 말고 딕셔너리에서 추출해서 더하도록 하세요.

# %% [markdown]
# 20. 딕셔너리 student2에서 update를 이용하여 'english' 는 100, 'history'는 80를 입력하세요.

# %% [markdown]
# 21. courses라는 변수에 dict() 함수를 사용하여 다음과 같은 딕셔너리를 생성하세요.
# ```
# {'programming': {'python': 50, 'java': 30, 'Cpp': 20},
#  'design': {'Photoshop': 25, 'Illustrator': 15}}
#  ```

# %% [markdown]
# 22. "python"의 수강생 수를 출력하세요.

# %% [markdown]
# 23. 딕셔너리 courses에서 "Cpp" 수강생 수를 25로 변경하고 출력하세요.

# %% [markdown]
# 24. 딕셔너리 courses에서 "Photoshop" 수강생 수를 삭제하고 출력하세요.

# %% [markdown]
# 25. 딕셔너리 courses에서 "JavaScript": 40을 "programming" 항목에 추가하고 출력하세요.

# %% [markdown]
# 26. 딕셔너리 courses의 모든 과목명을 출력하세요.

# %% [markdown]
# 27. 딕셔너리 courses에서 "design" 과목의 모든 정보를 출력하세요.

# %% [markdown]
# 28. 딕셔너리 courses에서 "design" 항목을 삭제하고 전체 딕셔너리를 출력하세요.

# %% [markdown]
# 29. 딕셔너리 courses에서 "programming" 항목이 존재하는지 확인하세요.

# %% [markdown]
# 30. 딕셔너리 courses에서 "design" 항목을 출력하고 "design" 이 없다면 design key 없음 이라고 출력하도록 하세요.
