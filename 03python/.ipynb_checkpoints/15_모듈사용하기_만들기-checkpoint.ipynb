# %% [markdown]
# # 모듈 사용하기
# * 누군가가 미리 사용하기 편하게 만들어 놓은 함수, 클래스
# * import 명령을 통해서 프로그램 가장 위에서 모듈을 불러와 사용할 수 있음.
# * 모듈에 너무 많은 기능이 있는 경우 from 모듈명 import 함수/메서드명 형식으로 일부 기능만 불러올 수도 있음.
# * 모듈은 사용자가 직접 만들 수도 있음.
# * 사용자 모듈을 불러올 때는 실행하는 파일과 같은 위치에 있어야 함.

# %% [markdown]
# # datetime 모듈 사용하기

# %%
from datetime import datetime

# %%
datetime.now()
# Out:
# datetime.datetime(2026, 1, 19, 12, 19, 21, 808947)

# %%
now = datetime.now()

# %%
now.year
# Out:
# 2026

# %%
now.month
# Out:
# 1

# %%
now.day
# Out:
# 19

# %%
print("now", type(now))
print("now.year", type(now.year))
print('f"{now.year}"', type(f"{now.year}"))
# Out:
# now <class 'datetime.datetime'>
# now.year <class 'int'>
# f"{now.year}" <class 'str'>

# %%
# 2026-01-19
print(f"{now.year}-{now.month:02d}-{now.day:02d}")
# Out:
# 2026-01-19

# %%
now.hour
# Out:
# 12

# %%
now.minute
# Out:
# 19

# %%
now.second
# Out:
# 21

# %% [markdown]
# * 시간을 포멧에 맞춰 출력하기
#   * strftime(출력 서식)

# %%
now.strftime("%Y.%m.%d %H:%M:%S")
# Out:
# '2026.01.19 12:19:21'

# %%
now.strftime("%y.%h.%d %H:%M:%S")
# Out:
# '26.Jan.19 12:19:21'

# %% [markdown]
# # OS 모듈
# * cmd 명령어를 쓸 수 있게

# %%
import os

# %%
# 내가 사용하는 컴퓨터의 기본정보 출력하기
print("현재 운영체제:", os.name)
# Out:
# 현재 운영체제: nt

# %%
print("현재 사용하는 폴더:", os.getcwd())
# Out:
# 현재 사용하는 폴더: c:\fintech4\03python

# %%
# 파일 리스트
print("현재 폴더 내부의 파일 리스트:", os.listdir())
# Out:
# 현재 폴더 내부의 파일 리스트: ['.ipynb_checkpoints', '00_jupyter_markdown_강의안.html', '00주피터노트북_사용법.ipynb', '00파이썬가상환경_miniforge.html', '00파이썬가성환경_miniforge_연습문제.html', '01_파이썬문법기초.ipynb', '02_파이썬의_자료형_학생용.ipynb', '03_Miniforge_주피터노트북 설치 및 설정.pdf', '03_연산자의_종류와_활용_학생용.ipynb', '06_딕셔너리 사용하기.ipynb', '06_리스트와_튜플_사탕상자_강의안.html', '07_서식지정자, format 메서드, f-string.ipynb', '08_if_else조건문.ipynb', '08리스트_튜플_딕셔너리_쉬운강의안.html', '09_반복문_for_while.ipynb', '10_리스트표현식_파일읽기쓰기.ipynb', '11_JSON파일_정리해서_DataFrame으로_만들어_csv로_저장하기.ipynb', '12_호텔스닷컴_JSON_언패킹_과제.ipynb', '13_함수만들기_예외처리.ipynb', '13함수만들기_예외처리_상세강의안.html', '14JSON언패킹2_호텔스닷컴리뷰json구조.txt', '14_클래스 만들기.ipynb', '15_모듈사용하기_만들기.ipynb', '15클래스_강의안_커피머신_비유_통합본_v5.html', '16datetime모듈사용하기_강의안.html', 'data', 'myfunc.py', 'styles.css', 'testdir', '__pycache__', '강_04문자열과 문자열 함수.ipynb', '강_05리스트와_튜플사용하기_시퀀스객체.ipynb', '강_12호텔스닷컴_JSON_언패킹_과제.ipynb', '문자열_연습문제.txt', '연습문제_00_Jupyter_Markdown_30.ipynb', '연습문제_00_jupyter_markdown_30문제.html', '연습문제_01_print_자료형_연산자 연습문제_오답수정.html', '연습문제_01_print_자료형_연산자.ipynb', '연습문제_03_리스트_튜플_20문제.ipynb', '연습문제_03_리스트_튜플_연습문제.html', '연습문제_03_리스트_튜플_연습문제_정답수정.html', '연습문제_04_딕셔너리_30문제.ipynb', '연습문제_04_딕셔너리_연습문제.html', '연습문제_05_딕셔너리_조건문_반복문연습문제.html', '연습문제_05_딕셔너리_조건문_반복문연습문제_48문제.ipynb', '연습문제_07_서식지정자와_문자열_포맷팅_연습문제.html', '연습문제_09_함수만들기_예외처리_연습문제.html', '연습문제_10_클래스만들기_연습문제.html', '초보자를_위한_파이썬_300제_001-100.ipynb', '초보자를_위한_파이썬_300제_101-200.ipynb']

# %%
# ipynb 파일 목록만 만들기
print(type(os.listdir()))
# Out:
# <class 'list'>

# %%
file_list = os.listdir()
file_list[0]
# Out:
# '.ipynb_checkpoints'

# %%
ipynb_list = []
for file in file_list:
#    print(file, type(file))
    if file[-5:] == "ipynb":
        ipynb_list.append(file)
ipynb_list
# Out:
# ['00주피터노트북_사용법.ipynb',
#  '01_파이썬문법기초.ipynb',
#  '02_파이썬의_자료형_학생용.ipynb',
#  '03_연산자의_종류와_활용_학생용.ipynb',
#  '06_딕셔너리 사용하기.ipynb',
#  '07_서식지정자, format 메서드, f-string.ipynb',
#  '08_if_else조건문.ipynb',
#  '09_반복문_for_while.ipynb',
#  '10_리스트표현식_파일읽기쓰기.ipynb',
#  '11_JSON파일_정리해서_DataFrame으로_만들어_csv로_저장하기.ipynb',
#  '12_호텔스닷컴_JSON_언패킹_과제.ipynb',
#  '13_함수만들기_예외처리.ipynb',
#  '14_클래스 만들기.ipynb',
#  '15_모듈사용하기_만들기.ipynb',
#  '강_04문자열과 문자열 함수.ipynb',
#  '강_05리스트와_튜플사용하기_시퀀스객체.ipynb',
#  '강_12호텔스닷컴_JSON_언패킹_과제.ipynb',
#  '연습문제_00_Jupyter_Markdown_30.ipynb',
#  '연습문제_01_print_자료형_연산자.ipynb',
#  '연습문제_03_리스트_튜플_20문제.ipynb',
#  '연습문제_04_딕셔너리_30문제.ipynb',
#  '연습문제_05_딕셔너리_조건문_반복문연습문제_48문제.ipynb',
#  '초보자를_위한_파이썬_300제_001-100.ipynb',
#  '초보자를_위한_파이썬_300제_101-200.ipynb']

# %% [markdown]
# * data 폴더에서 csv 파일 목록만 가져오기

# %%
csv_list = []
for file in os.listdir("./data"):
#    print(file)
    if file[-3:] == "csv":
        csv_list.append(file)
csv_list
# Out:
# ['국민은행_앱리뷰.csv', '서울시관광지입장객정보.csv', '전국_치킨집_리스트.csv']

# %%
# os.listdir("../")

# %%
os.getcwd()
# Out:
# 'c:\\fintech4\\03python'

# %%
# 현재 위치에서 폴더 만들기
os.mkdir("testdir")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[24], line 2
#       1 # 현재 위치에서 폴더 만들기
# ----> 2 os.mkdir("testdir")
#
# FileExistsError: [WinError 183] 파일이 이미 있으므로 만들 수 없습니다: 'testdir'

# %%
# 현재 위치에서 폴더 삭제하기
os.rmdir("testdir")

# %% [markdown]
# # 폴더가 있는지 확인하고 없으면 폴더 생성하기

# %%
dir_name = "testdir"
if not os.path.exists(dir_name):
    os.mkdir(dir_name)
    print(f"{dir_name}을 생성했습니다.")
else:
    print(f"{dir_name}이 이미 있습니다.")

# %% [markdown]
# # 내 모듈 만들기
# * .py 형식으로 내 모듈을 만들 수 있다.
# * .py 파일 안에는 함수를 정의해야 한다.
# * .py 파일은 모듈을 불러오는 파일과 같은 위치에 있어야 한다.

# %% [markdown]
# * Cal 클래스와 add라는 함수를 모듈로 만들과 불러와서 사용하기

# %%
import myfunc

# %%
add(3, 5)

# %%
myfunc.add(3, 5)

# %%
sam = myfunc.Cal(3, 5)

# %%
sam.add()

# %%
sam.sub()

# %%
sam.mul()

# %%
sam.div()

# %% [markdown]
# # 약칭을 사용해서 모듈명 축약해서 사용하기

# %%
import myfunc as mf

# %%
mf.add(3, 7)

# %%
sam2 = mf.Cal(3, 7)

# %%
sam2.add()

# %%
sam2.div()

# %% [markdown]
# # 모듈에서 일부 함수나 클래스만 따로 불러올 때
# ```python
# from 모듈명 import 함수/클래스명, 함수2/클래스명2
# ```

# %%
from myfunc import add, Cal

# %%
add(10, 20)
# Out:
# 30

# %%
dul = Cal(10, 0)

# %%
dul.div()
# Out:
# 0

# %%
from myfunc import text_clean

# %%
test =
